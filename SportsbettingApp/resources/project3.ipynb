# %%
#! pip install psycopg2
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine
import numpy as np
# !pip3 install psycopg2

# %%
#NFL TABLE
NFL_file = "../resources/NFL_Opening_Odds2.csv"
NFL_df = pd.read_csv(NFL_file)
NFL_df.head()
# Out:
#              Home_Team                 Away_Team  Winner_Home  Odds_Home  \
# 0     Baltimore Ravens            Dallas Cowboys         True       1.27
# 1  San Francisco 49ers             Buffalo Bills        False       2.35
# 2  Pittsburgh Steelers  Washington Football Team        False       1.22
# 3   Kansas City Chiefs            Denver Broncos         True       1.12
# 4    Green Bay Packers       Philadelphia Eagles         True       1.23
#
#    Odds_Away
# 0       3.80
# 1       1.64
# 2       4.50
# 3       6.50
# 4       4.25

# %%
#Horseracing TABLE
Horseracing_file = "../resources/tips2.csv"
Horseracing_df = pd.read_csv(Horseracing_file)
Horseracing_df.head()
# Out:
#        Track              Horse BetType  Odds Winner
# 0      Ascot          Fredricka     Win  8.00   Lose
# 1     Thirsk      Spend A Penny     Win  4.50   Lose
# 2       York  Straightothepoint     Win  7.00   Lose
# 3  Newmarket     Miss Inga Sock     Win  5.00   Lose
# 4      Ascot              Peril     Win  4.33    Win

# %%
#UFC TABLE
UFC1_file = "../Resources/UFC1.csv"
UFC1_df = pd.read_csv(UFC1_file)
UFC1_df.head()
# Out:
#    Red_Corner_Fighter Blue_Corner_Fighter  Odds_Red_Fighter  \
# 0           Kevin Lee    Charles Oliveira              -145
# 1         Demian Maia       Gilbert Burns               160
# 2      Renato Moicano      Damir Hadzovic              -345
# 3       Johnny Walker       Nikita Krylov              -137
# 4  Francisco Trinaldo       John Makdessi              -160
#
#    Odds_Blue_Fighter Winner
# 0                135   Blue
# 1               -170   Blue
# 2                315    Red
# 3                127   Blue
# 4                150    Red

# %%
engine = create_engine('postgres://bwxormoq:eKtYIkVXGTjFJYwGePZHd1aSVOFZtjkP@ziggy.db.elephantsql.com:5432/bwxormoq')
# conn = engine.connect()

# %%
engine.table_names()
# Out:
# ['NFL', 'Horseracing', 'UFC1']

# %%
conn.close()

# %%
NFL_df.to_sql(name='NFL',con=engine, if_exists='replace', index=True)
Horseracing_df.to_sql(name='Horseracing', con=engine, if_exists='append', index=True)
UFC1_df.to_sql(name='UFC1',con=engine, if_exists='append', index=True)

# %%
from  sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session

# %%
engine
# Out:
# Engine(postgres://bwxormoq:***@ziggy.db.elephantsql.com:5432/bwxormoq)

# %%
Base=automap_base()

# %%
Base.prepare(engine, reflect=True)

# %%
Base.classes.keys()
# Out:
# ['NFL', 'Horseracing', 'UFC1']

# %%
NFLRoute=Base.classes.NFL

# %%
session = Session(engine)
results1 = session.query( 
NFLRoute.Home_Team, 
NFLRoute.Away_Team,
NFLRoute.Winner_Home, 
NFLRoute.Odds_Home, 
NFLRoute.Odds_Away).all()


result_list1 = []
    
for Home_Team, Away_Team, Winner_Home, Odds_Home, Odds_Away in results1:
    NFL = {}
    NFL["Home_Team"] = Home_Team
    NFL["Away_Team"] = Away_Team
    NFL["Winner_Home"] = Winner_Home
    NFL["Odds_Home"] = Odds_Home
    NFL["Odds_Away"] = Odds_Away
    result_list1.append(NFL)

# %%
result_list1
# Out:
# [{'Home_Team': 'Baltimore Ravens',
#   'Away_Team': 'Dallas Cowboys',
#   'Winner_Home': True,
#   'Odds_Home': 1.27,
#   'Odds_Away': 3.8},
#  {'Home_Team': 'San Francisco 49ers',
#   'Away_Team': 'Buffalo Bills',
#   'Winner_Home': False,
#   'Odds_Home': 2.35,
#   'Odds_Away': 1.64},
#  {'Home_Team': 'Pittsburgh Steelers',
#   'Away_Team': 'Washington Football Team',
#   'Winner_Home': False,
#   'Odds_Home': 1.22,
#   'Odds_Away': 4.5},
#  {'Home_Team': 'Kansas City Chiefs',
#   'Away_Team': 'Denver Broncos',
#   'Winner_Home': True,
#   'Odds_Home': 1.12,
#   'Odds_Away': 6.5},
#  {'Home_Team': 'Green Bay Packers',
#   'Away_Team': 'Philadelphia Eagles',
#   'Winner_Home': True,
#   'Odds_Home': 1.23,
#   'Odds_Away': 4.25},
#  {'Home_Team': 'Los Angeles Chargers',
#   'Away_Team': 'New England Patriots',
#   'Winner_Home': False,
#   'Odds_Home': 1.8,
#   'Odds_Away': 2.05},
#  {'Home_Team': 'Arizona Cardinals',
#   'Away_Team': 'Los Angeles Rams',
#   'Winner_Home': False,
# ...

# %%
engine.execute('Alter table "NFL" add primary key (index)')

# %%
engine.execute('Alter table "Horseracing" add primary key (index)')

# %%
engine.execute('Alter table "UFC1" add primary key (index)')

# %%
pd.read_sql('select * from "NFL"', engine)
# Out:
#       index            Home_Team                 Away_Team  Winner_Home  \
# 0         0     Baltimore Ravens            Dallas Cowboys         True
# 1         1  San Francisco 49ers             Buffalo Bills        False
# 2         2  Pittsburgh Steelers  Washington Football Team        False
# 3         3   Kansas City Chiefs            Denver Broncos         True
# 4         4    Green Bay Packers       Philadelphia Eagles         True
# ...     ...                  ...                       ...          ...
# 2476   2476       Dallas Cowboys          Seattle Seahawks         True
# 2477   2477        Buffalo Bills             New York Jets        False
# 2478   2478    Arizona Cardinals            St. Louis Rams         True
# 2479   2479   Kansas City Chiefs        San Diego Chargers         True
# 2480   2480     Tennessee Titans        Indianapolis Colts         True
#
#       Odds_Home  Odds_Away
# 0      1.270000      3.800
# 1      2.350000      1.640
# ...
